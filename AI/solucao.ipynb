# %% [markdown]
# # PI - NLP

# %% [markdown]
# Autor: <font color=red>Roger Ribeiro Fava Pina</font>

# %% [markdown]
# Enunciado do problema
# Um problema que as empresas varejistas têm é o de conseguir entender pontos em que podem melhorar seus serviços. Para isso, precisam de dados, que geralmente são conseguidos em pesquisas de opinião ou no registro do comportamento de compras - por exemplo, se todos os clientes deixam de comprar um determinado produto, isso pode significar que mantê-lo nas prateleiras é um ônus para um supermercado. No caso do e-commerce, o acesso a dados tem a característica de permitir que usuários que fizeram compras registrem suas impressões por meio de estrelas (1 a 5 estrelas) e comentários.
#
# Os comentários são tipicamente dados não-estruturados, isto é, o usuário é livre para escrever o que quiser. Por isso, são uma fonte rica de informações e, ao mesmo tempo, uma fonte difícil de lidar, já que é preciso usar técnicas de NLP para entender o que está sendo dito.
#
# Neste exercício, utilizaremos a base de dados disponibilizada pela Olist em:
#
# https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
#
# para descobrir: <font color=red>Quais são os fatores que mais aborrecem os clientes em suas compras online?</font>

# %%
import joblib
import urllib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import train_test_split
from keras.layers import Input, Dense, Activation
from keras.models import Model
import tensorflow as tf
from tensorflow.keras.utils import plot_model

from sklearn.feature_extraction.text import TfidfVectorizer

url = "https://gist.githubusercontent.com/alopes/5358189/raw/2107d809cca6b83ce3d8e04dbd9463283025284f/stopwords.txt"
stopwords_list = urllib.request.urlopen(url).read().decode()
stopwords_ptbr = set(stopwords_list.split())
stopwords_ptbr.remove('não')

# %%
csv_path = "data/olist_order_reviews_dataset.csv"
df_ = pd.read_csv(csv_path)

# %%
df_
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [99224 rows x 7 columns]

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## Limpando do Dataset

# %% [markdown]
# - Eliminar célular em branco

# %%
df_ = df_[['review_score', 'review_comment_message']]

# %% [markdown]
# Mantive apenas as colunas interessantes para análise. Sendo elas o score, título do comentário e comentário em si.

# %% [markdown]
# ### Removendo todos "nan"

# %%
df_drop_na = df_.dropna()

# %%
df_drop_na.describe()
# Out:
#        review_score
# count  40977.000000
# mean       3.669864
# std        1.615418
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
(df_drop_na.describe().iloc[0].values[0] / df_.describe().iloc[0].values[0]) * 100
# Out:
# 41.29746835443038

# %% [markdown]
# Ao dropar todos "Nan"s do dataset sobram menos de 10000 linhas, menos de 10% dos dados originais. Entretanto, dentre as 3 colunas de dados que serão utilizadas, a que será capaz de fornecer informação suficiente para responder quais são os fatores que mais aborrecem os clientes em suas compras online é a coluna: "review_comment_message". Com isso, irei remover apenas as linhas que possuem Nan nessa coluna.

# %% [markdown]
# ### Removendo todos "nan" da coluna "review_comment_message"

# %%
df_drop_na_msg = df_[df_['review_comment_message'].notna() & df_['review_score'].notna() ]

# %%
df_drop_na_msg.describe()
# Out:
#        review_score
# count  40977.000000
# mean       3.669864
# std        1.615418
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
(df_drop_na_msg.describe().iloc[0].values[0] / df_.describe().iloc[0].values[0]) * 100
# Out:
# 41.29746835443038

# %% [markdown]
# Com essa limpeza sobram mais de 40% dos dados inicias, uma quantidade maior que a outra remoção de dados testada além de que mantém dados capazes de trazer mais informação.

# %%
df = df_drop_na_msg

# %% [markdown]
# ## Feature-enginerring

# %%
df
df_orig = df.copy()

# %%
# Encode scores to be Satisfied or Not Satisfied
encoded_class = { 1 : 'Aborrecido',
                  2 : 'Aborrecido', 
                  3 : 'Aborrecido', 
                  4 : 'Satisfeito', 
                  5 : 'Satisfeito'}

df_orig['review_score'] = df_orig['review_score'].map(encoded_class)
df['review_score'] = df['review_score'].map(encoded_class)
# Out:
# C:\Users\roger\AppData\Local\Temp\ipykernel_1920\3615129537.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review_score'] = df['review_score'].map(encoded_class)

# %% [markdown]
# ## Tokenização

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()
REGEX = r'\b\w+\b'

def clean_comments(comment):
    text = re.findall(REGEX, comment.lower())
    text = [stemmer.stem(word) for word in text if word not in stopwords_ptbr]
    text = ' '.join(text)
    return text

df['review_comment_message'] = df['review_comment_message'].apply(lambda x: clean_comments(x))
# Out:
# C:\Users\roger\AppData\Local\Temp\ipykernel_1920\1341785413.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review_comment_message'] = df['review_comment_message'].apply(lambda x: clean_comments(x))

# %%
df
# Out:
#       review_score                             review_comment_message
# 3       Satisfeito                    recebi bem ant prazo estipulado
# 4       Satisfeito  parabén loja lannist adorei comprar internet s...
# 9       Satisfeito  aparelho eficient site marca aparelho impresso...
# 12      Satisfeito                        pouco travando valor ta boa
# 15      Satisfeito    vendedor confiável produto ok entrega ant prazo
# ...            ...                                                ...
# 99205   Satisfeito             produto recebi acordo compra realizada
# 99208   Satisfeito  entreg dentro prazo produto chegou condiçõ per...
# 99215   Aborrecido  produto não enviado nf não exist venda nf cert...
# 99221   Satisfeito  excelent mochila entrega super rápida super re...
# 99223   Aborrecido  produto chegou ja devolv poi defeito não segur...
#
# [40977 rows x 2 columns]

# %% [markdown]
# # Análise de sentimentos

# %%
X = df['review_comment_message']
y = df['review_score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.6, stratify=y)

# %%
classificador = Pipeline([
    ('meu_vetorizador', CountVectorizer(stop_words=stopwords_ptbr)),
    ('meu_classificador', LogisticRegression(solver='saga', max_iter=10000))
])

# %%
classificador.fit(X_train, y_train)
y_pred = classificador.predict(X_test)
acc = accuracy_score(y_pred, y_test)
print(acc)
# Out:
# 0.891769873711183

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classificador, X_train, y_train)
plot_confusion_matrix(classificador, X_test, y_test)
# Out:
# C:\Users\roger\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\roger\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Identificação dos fatores de aborrecimento

# %%
df_aborrecido = df[df.review_score == 'Aborrecido']

# Reset index
df_aborrecido.reset_index(inplace= True, drop= True)

# %%
df_aborrecido
# Out:
#       review_score                             review_comment_message
# 0       Aborrecido  gostaria saber sempr recebi compra agora decpcion
# 1       Aborrecido                                            péssimo
# 2       Aborrecido                       não gostei comprei gato lebr
# 3       Aborrecido  sempr compro internet entrega ocorr ant prazo ...
# 4       Aborrecido                                 nada chegar pedido
# ...            ...                                                ...
# 14442   Aborrecido  bom dia 6 unidad comprada recebi 4 unidad agua...
# 14443   Aborrecido  foto diferent principalment graninha sintética...
# 14444   Aborrecido  problema entrega correio coloc site entregu di...
# 14445   Aborrecido  produto não enviado nf não exist venda nf cert...
# 14446   Aborrecido  produto chegou ja devolv poi defeito não segur...
#
# [14447 rows x 2 columns]

# %%
vocab = dict()
for text in df_aborrecido['review_comment_message']:
    text = text.split()
    for word in text:
        if word not in vocab:
            vocab[word] = 0
        vocab[word] += 1

# %%
vocab_list = []
for word, freq in vocab.items():
    for e in range(freq):
        vocab_list.append(word)
np.random.shuffle(vocab_list)

# %%
from wordcloud import WordCloud

non_satisfied_final = ' '.join(vocab_list)
non_satisfied_freq = WordCloud(width=1000, height=800, background_color='white').generate(non_satisfied_final)

plt.figure(figsize=(15, 10))
plt.imshow(non_satisfied_freq)
plt.axis("off")
# Out:
# (-0.5, 999.5, 799.5, -0.5)

# %%
# Sort the word frequencies in descending order
non_satisfied_freq = non_satisfied_freq.process_text(non_satisfied_final)
sorted_word_frequencies = sorted(non_satisfied_freq.items(), key= lambda x : x[1], reverse=True)

# %%
import seaborn as sns
# Plot Words vs Frequency
plt.figure(figsize= [20, 10])
sns.barplot(x = pd.DataFrame(sorted_word_frequencies)[1:20][0], y= pd.DataFrame(sorted_word_frequencies)[1:20][1], palette= 'crest_r')
plt.title('Top 20 Words and their Frequinces', fontsize= 15)
plt.xlabel('Words', fontsize= 12)
plt.ylabel('Frequency', fontsize= 12)
sns.despine()

# %%
def get_ngrams_and_res(tokens, N):
    ngrams = [tuple(tokens[i:i+N]) for i in range(len(tokens)-N)]
    res = [tokens[i+N] for i in range(len(tokens)-N)]
    return ngrams, res

# Criar vocabulário
vocab_ngrams = set()
all_ngrams = []
all_res = []
for text in df_aborrecido['review_comment_message']:
    tokens = re.findall(REGEX, text.lower())
    n_grams,res = get_ngrams_and_res(tokens, 4)
    all_ngrams += n_grams
    all_res += res
    vocab_ngrams = vocab_ngrams.union(set(n_grams))

# %%
ngrams_dict = dict()
for ngram in all_ngrams:
    if ngram not in ngrams_dict:
        ngrams_dict[ngram] = 0
    ngrams_dict[ngram] += 1

# %%
sorted_ngrams_frequencies = sorted(ngrams_dict.items(), key= lambda x : x[1], reverse=True)

# %%
import seaborn as sns
# Plot Words vs Frequency
plt.figure(figsize= [8, 10])
sns.barplot(x = pd.DataFrame(sorted_ngrams_frequencies)[0:20][1], y= pd.DataFrame(sorted_ngrams_frequencies)[0:20][0], palette= 'crest_r')
plt.title('Top 20 Ngrams and their Frequences', fontsize= 15)
plt.xlabel('Frequency', fontsize= 12)
plt.ylabel('Words', fontsize= 12)
sns.despine()

# %%
sorted_ngrams_frequencies
# Out:
# [(('ainda', 'não', 'recebi', 'produto'), 130),
#  (('não', 'recebi', 'produto', 'não'), 52),
#  (('produto', 'ainda', 'não', 'entregu'), 38),
#  (('produto', 'ainda', 'não', 'chegou'), 30),
#  (('momento', 'não', 'recebi', 'produto'), 29),
#  (('não', 'recebi', 'produto', 'ainda'), 25),
#  (('produto', 'chegou', 'ant', 'prazo'), 23),
#  (('agora', 'não', 'recebi', 'produto'), 23),
#  (('não', 'recebi', 'produto', 'comprei'), 21),
#  (('ainda', 'nao', 'recebi', 'produto'), 18),
#  (('produto', 'entregu', 'dentro', 'prazo'), 17),
#  (('poi', 'ainda', 'não', 'recebi'), 17),
#  (('não', 'recebi', 'produto', 'prazo'), 16),
#  (('produto', 'não', 'entregu', 'prazo'), 15),
#  (('comprei', 'doi', 'produto', 'recebi'), 14),
#  (('produto', 'não', 'entregu', 'não'), 14),
#  (('produto', 'veio', 'defeito', 'não'), 14),
#  (('recebi', 'produto', 'dentro', 'prazo'), 14),
#  (('não', 'recebi', 'produto', 'comprado'), 12),
#  (('não', 'recebi', 'produto', 'gostaria'), 12),
#  (('produto', 'não', 'chegou', 'prazo'), 11),
#  (('dia', 'ainda', 'não', 'recebi'), 11),
#  (('não', 'obtiv', 'nenhuma', 'resposta'), 11),
#  (('present', 'data', 'não', 'recebi'), 11),
#  (('present', 'momento', 'não', 'recebi'), 11),
#  (('comprei', 'produto', 'recebi', 'outro'), 11),
#  (('não', 'recebi', 'ainda', 'produto'), 10),
#  (('entrega', 'ainda', 'não', 'recebi'), 10),
#  (('hoje', 'não', 'recebi', 'produto'), 10),
#  (('não', 'consigo', 'entrar', 'contato'), 10),
#  (('chegou', 'bem', 'ant', 'prazo'), 9),
#  (('recebi', 'produto', 'ainda', 'não'), 9),
#  (('não', 'recebi', 'produto', 'quero'), 9),
#  (('produto', 'não', 'chegou', 'não'), 9),
#  (('não', 'recebi', 'produto', 'hoje'), 9),
#  (('não', 'recebi', 'produto', 'momento'), 9),
#  (('comprei', 'dua', 'unidad', 'recebi'), 8),
#  (('não', 'recebi', 'produto', 'correto'), 8),
#  (('produto', 'não', 'entregu', 'ainda'), 8),
#  (('produto', 'chegou', 'dentro', 'prazo'), 8),
#  (('recebi', 'produto', 'porém', 'veio'), 8),
#  (('recebi', 'produto', 'gostaria', 'saber'), 8),
#  (('nao', 'recebi', 'produto', 'nao'), 8),
#  (('ainda', 'não', 'recebi', 'pedido'), 8),
#  (('não', 'recomendo', 'loja', 'poi'), 8),
#  (('recebi', 'produto', 'não', 'consigo'), 7),
#  (('produto', 'não', 'veio', 'conform'), 7),
#  (('prazo', 'entrega', 'ainda', 'não'), 7),
#  (('ainda', 'não', 'entregu', 'não'), 7),
#  (('não', 'recebi', 'produto', 'enviei'), 7),
#  (('produto', 'não', 'entregu', 'quero'), 7),
#  (('boa', 'tard', 'recebi', 'produto'), 7),
#  (('produto', 'péssima', 'qualidad', 'não'), 7),
#  (('avaliar', 'poi', 'ainda', 'não'), 7),
#  (('comprei', 'produto', 'não', 'entregu'), 7),
#  (('bom', 'dia', 'ainda', 'não'), 7),
#  (('recebi', 'produto', 'não', 'sei'), 7),
#  (('não', 'veio', 'nota', 'fiscal'), 7),
#  (('recebi', 'apena', '1', 'unidad'), 7),
#  (('não', 'gostei', 'qualidad', 'produto'), 7),
#  (('não', 'recebi', 'produto', 'poi'), 7),
#  (('dia', 'não', 'recebi', 'produto'), 7),
#  (('ainda', 'não', 'chegou', 'não'), 7),
#  (('não', 'recebi', 'pedido', 'completo'), 7),
#  (('quero', 'dinheiro', 'volta', 'não'), 7),
#  (('produto', 'entregu', 'ant', 'prazo'), 7),
#  (('produto', 'não', 'chegou', 'ainda'), 7),
#  (('comprei', 'produto', 'veio', 'outro'), 6),
#  (('não', 'consigo', 'falar', 'ninguém'), 6),
#  (('paguei', 'frete', 'não', 'recebi'), 6),
#  (('não', 'cumpriram', 'prazo', 'entrega'), 6),
#  (('não', 'recebi', 'produto', 'nenhuma'), 6),
#  (('passou', 'prazo', 'entrega', 'ainda'), 6),
#  (('apesar', 'estar', 'dentro', 'prazo'), 6),
#  (('produto', 'entregu', 'prazo', 'porém'), 6),
#  (('não', 'recebi', 'produto', 'paguei'), 6),
#  (('entrega', 'agora', 'não', 'recebi'), 6),
#  (('não', 'recebi', 'produto', 'sendo'), 6),
#  (('recebi', 'produto', 'ant', 'prazo'), 6),
#  (('ainda', 'não', 'recebi', 'mercadoria'), 6),
#  (('ainda', 'não', 'recebi', 'não'), 6),
#  (('não', 'recebi', 'produto', 'ninguém'), 6),
#  (('comprei', 'dua', 'unidad', 'produto'), 6),
#  (('produto', 'chegou', 'prazo', 'porém'), 6),
#  (('não', 'recebi', 'produto', 'faz'), 6),
#  (('não', 'recebi', 'produto', 'vou'), 6),
#  (('não', 'recebi', 'pedido', 'não'), 6),
#  (('comprei', 'doi', 'produto', 'iguai'), 6),
#  (('não', 'recebi', 'produto', 'consta'), 5),
#  (('dua', 'unidad', 'recebi', 'apena'), 5),
#  (('recebi', 'produto', 'errado', 'comprei'), 5),
#  (('não', 'consigo', 'contato', 'lannist'), 5),
#  (('não', 'posso', 'avaliar', 'não'), 5),
#  (('não', 'recebi', 'produto', 'data'), 5),
#  (('não', 'recebi', 'produto', 'loja'), 5),
#  (('não', 'recebi', 'produto', 'apesar'), 5),
#  (('ate', 'agora', 'não', 'recebi'), 5),
#  (('não', 'entreg', 'produto', 'não'), 5),
#  (('entrega', 'produto', 'ainda', 'não'), 5),
#  (('não', 'recebi', 'nenhuma', 'satisfação'), 5),
#  (('ate', 'agora', 'nao', 'recebi'), 5),
#  (('entrega', 'não', 'recebi', 'produto'), 5),
#  (('prazo', 'entrega', 'produto', 'não'), 5),
#  (('não', 'recebi', 'nenhuma', 'informação'), 5),
#  (('ja', 'passou', 'prazo', 'entrega'), 5),
#  (('entregu', 'porém', 'não', 'recebi'), 5),
#  (('infelizment', 'não', 'recebi', 'produto'), 5),
#  (('não', 'recebi', 'produto', 'statu'), 5),
#  (('não', 'recebi', 'produto', 'passou'), 5),
#  (('sempr', 'comprei', 'loja', 'lannist'), 5),
#  (('recebi', 'produto', 'prazo', 'entrega'), 5),
#  (('ainda', 'não', 'chegou', 'unidad'), 5),
#  (('dentro', 'prazo', 'porém', 'produto'), 5),
#  (('gostaria', 'saber', 'vou', 'receb'), 5),
#  (('não', 'gostei', 'produto', 'não'), 5),
#  (('comprei', 'doi', 'produto', 'chegou'), 5),
#  (('momento', 'não', 'recebi', 'nenhuma'), 5),
#  (('não', 'recebi', 'produto', 'site'), 5),
#  (('ate', 'momento', 'não', 'recebi'), 5),
#  (('agora', 'não', 'entraram', 'contato'), 5),
#  (('produto', 'não', 'entregu', 'gostaria'), 5),
#  (('produto', 'pra', 'entregu', 'dia'), 5),
#  (('data', 'não', 'recebi', 'produto'), 5),
#  (('produto', 'agora', 'não', 'recebi'), 5),
#  (('empresa', 'não', 'entrou', 'contato'), 5),
#  (('não', 'entraram', 'contato', 'comigo'), 5),
#  (('não', 'obtiv', 'nenhum', 'retorno'), 5),
#  (('poi', 'não', 'recebi', 'produto'), 5),
#  (('ainda', 'não', 'posso', 'avaliar'), 5),
#  (('produto', 'recebi', 'apena', '1'), 5),
#  (('1', 'preto', '1', 'colorido'), 5),
#  (('chegou', 'ant', 'prazo', 'porém'), 5),
#  (('produto', 'não', 'origin', 'não'), 5),
#  (('nao', 'recebi', 'produto', 'ainda'), 5),
#  (('30', 'dia', 'não', 'recebi'), 4),
#  (('ate', 'agora', 'nao', 'chegou'), 4),
#  (('não', 'recebi', 'produto', 'completo'), 4),
#  (('produto', 'bom', 'porém', 'não'), 4),
#  (('produto', 'não', 'veio', 'cor'), 4),
#  (('recebi', 'produto', 'diferent', 'comprei'), 4),
#  (('pedi', 'dua', 'unidad', 'produto'), 4),
#  (('comprei', 'produto', 'enviaram', 'outro'), 4),
#  (('não', 'recebi', 'quero', 'saber'), 4),
#  (('comprei', 'produto', 'não', 'recebi'), 4),
#  (('present', 'momento', 'produto', 'não'), 4),
#  (('empresa', 'não', 'entreg', 'produto'), 4),
#  (('entrar', 'contato', 'lannist', 'não'), 4),
#  (('recebi', 'produto', 'quero', 'dinheiro'), 4),
#  (('não', 'entregu', 'consta', 'site'), 4),
#  (('não', 'chegou', 'passou', 'prazo'), 4),
#  (('ir', 'correio', 'retirar', 'produto'), 4),
#  (('não', 'recebi', 'produto', 'recebi'), 4),
#  (('entrega', 'super', 'rápida', 'produto'), 4),
#  (('ate', 'momento', 'nao', 'recebi'), 4),
#  (('apena', '1', 'nota', 'fiscal'), 4),
#  (('produto', 'não', 'boa', 'qualidad'), 4),
#  (('ainda', 'não', 'entregu', 'prazo'), 4),
#  (('ainda', 'não', 'recebi', 'outro'), 4),
#  (('bom', 'dia', 'comprei', '2'), 4),
#  (('comprei', '2', 'produto', 'recebi'), 4),
#  (('paguei', 'frete', 'retirar', 'correio'), 4),
#  (('não', 'avaliar', 'poi', 'ainda'), 4),
#  (('prazo', 'entrega', 'produto', 'dia'), 4),
#  (('recebi', 'produto', 'passou', 'prazo'), 4),
#  (('produto', 'não', 'entregu', 'momento'), 4),
#  (('comprei', 'kit', 'carrinho', 'bebê'), 4),
#  (('kit', 'carrinho', 'bebê', 'conforto'), 4),
#  (('ainda', 'não', 'entregaram', 'produto'), 4),
#  (('entregu', 'dentro', 'prazo', 'porém'), 4),
#  (('prazo', 'porém', 'produto', 'veio'), 4),
#  (('2', 'unidad', 'recebi', 'apena'), 4),
#  (('não', 'recebi', 'produto', 'acredito'), 4),
#  (('não', 'entrou', 'contato', 'comigo'), 4),
#  (('comprei', '2', 'unidad', 'veio'), 4),
#  (('não', 'recebi', 'produto', 'conform'), 4),
#  (('produto', 'ainda', 'nao', 'chegou'), 4),
#  (('não', 'recebi', 'produto', 'solicitei'), 4),
#  (('não', 'posso', 'avaliar', 'loja'), 4),
#  (('recebi', 'produto', 'totalment', 'diferent'), 4),
#  (('03', 'momento', 'não', 'recebi'), 4),
#  (('gostaria', 'saber', 'vai', 'ficar'), 4),
#  (('pedido', 'ainda', 'não', 'recebi'), 4),
#  (('recebi', 'produto', 'correto', 'porém'), 4),
#  (('produto', 'bem', 'diferent', 'foto'), 4),
#  (('entregu', 'bem', 'ant', 'prazo'), 4),
#  (('present', 'data', 'produto', 'não'), 4),
#  (('não', 'posso', 'avaliar', 'poi'), 4),
#  (('posso', 'avaliar', 'poi', 'ainda'), 4),
#  (('recebi', 'produto', 'errado', 'não'), 4),
#  (('produto', 'errado', 'não', 'consigo'), 4),
#  (('bom', 'dia', 'fiz', 'compra'), 4),
#  (('produto', 'dentro', 'prazo', 'porém'), 4),
#  (('não', 'recebi', 'produto', 'aguardando'), 4),
#  (('não', 'entregu', 'gostaria', 'saber'), 4),
#  (('produto', 'veio', 'errado', 'pedi'), 4),
#  (('recebi', 'apena', '1', 'produto'), 4),
#  (('não', 'recebi', 'produto', 'agora'), 4),
#  (('não', 'recebi', 'dinheiro', 'volta'), 4),
#  (('dia', 'ainda', 'não', 'chegou'), 4),
#  (('prazo', 'ainda', 'não', 'recebi'), 4),
#  (('dua', 'unidad', 'produto', 'recebi'), 4),
#  (('recebi', 'produto', 'prazo', 'porém'), 4),
#  (('momento', 'produto', 'não', 'chegou'), 4),
#  (('compra', 'ainda', 'não', 'chegou'), 4),
#  (('momento', 'ainda', 'não', 'recebi'), 4),
#  (('comprei', 'produto', 'cor', 'azul'), 4),
#  (('produto', 'péssima', 'qualidad', 'veio'), 4),
#  (('produto', 'não', 'correspondeu', 'expectativa'), 4),
#  (('produto', 'veio', 'incompleto', 'faltando'), 4),
#  (('porqu', 'produto', 'ainda', 'não'), 4),
#  (('momento', 'não', 'recebi', 'nenhum'), 4),
#  (('não', 'recebi', 'nenhum', 'retorno'), 4),
#  (('receb', 'produto', 'casa', 'não'), 4),
#  (('loja', 'não', 'entreg', 'produto'), 4),
#  (('nota', 'fiscal', 'emitida', 'não'), 4),
#  (('ainda', 'não', 'obtiv', 'resposta'), 4),
#  (('veze', 'não', 'obtiv', 'resposta'), 4),
#  (('sempr', 'comprei', 'lannist', 'nunca'), 4),
#  (('não', 'chegou', 'prazo', 'não'), 4),
#  (('dessa', 'vez', 'não', 'recebi'), 4),
#  (('comprei', 'produto', 'entregaram', 'outro'), 4),
#  (('produto', 'chegou', 'quebrado', 'não'), 4),
#  (('ant', 'prazo', 'porém', 'não'), 4),
#  (('bem', 'ant', 'prazo', 'previsto'), 4),
#  (('porqu', 'não', 'recebi', 'produto'), 4),
#  (('produto', 'entregu', 'não', 'produto'), 4),
#  (('não', 'recebi', 'nada', 'não'), 4),
#  (('produto', 'não', 'entregu', 'nenhuma'), 4),
#  (('não', 'recebi', 'produto', 'corretament'), 4),
#  (('comprei', 'produto', 'agora', 'não'), 4),
#  (('produto', 'não', 'chegou', 'dentro'), 4),
#  (('03', 'ainda', 'não', 'recebi'), 4),
#  (('bom', 'dia', 'não', 'recebi'), 4),
#  (('produto', 'ainda', 'nao', 'entregu'), 4),
#  (('mê', 'ainda', 'não', 'recebi'), 4),
#  (('não', 'recebi', 'produto', 'present'), 4),
#  (('momento', 'não', 'recebi', 'mercadoria'), 4),
#  (('control', 'remoto', 'ar', 'condicionado'), 3),
#  (('ant', 'emissão', 'nota', 'fiscal'), 3),
#  (('comprei', '2', 'cartucho', 'entregaram'), 3),
#  (('fiz', 'reclamação', 'agora', 'não'), 3),
#  (('insatisfeito', 'quero', 'dinheiro', 'volta'), 3),
#  (('comprei', '2', 'produto', 'so'), 3),
#  (('não', 'entregu', 'primeira', 'vez'), 3),
#  (('não', 'posso', 'dar', 'opinião'), 3),
#  (('produto', 'entregu', 'totalment', 'diferent'), 3),
#  (('produto', 'chegou', 'bem', 'ant'), 3),
#  (('recebi', 'produto', 'não', 'recebi'), 3),
#  (('produto', 'não', 'atendeu', 'expectativa'), 3),
#  (('tentei', 'entrar', 'contato', 'vária'), 3),
#  (('entrar', 'contato', 'vária', 'veze'), 3),
#  (('recebi', 'produto', 'momento', 'não'), 3),
#  (('produto', 'veio', 'faltando', 'peça'), 3),
#  (('infelizment', 'produto', 'veio', 'defeito'), 3),
#  (('não', 'gostei', 'não', 'recomendo'), 3),
#  (('não', 'cumpriu', 'prazo', 'entrega'), 3),
#  (('não', 'consigo', 'fazer', 'troca'), 3),
#  (('recebi', 'produto', 'loja', 'não'), 3),
#  (('chegou', 'ant', 'prazo', 'estipulado'), 3),
#  (('problema', 'não', 'loja', 'sim'), 3),
#  (('comprei', 'doi', 'kit', 'recebi'), 3),
#  (('momento', 'não', 'recebi', 'encomenda'), 3),
#  (('ainda', 'não', 'obtiv', 'nenhuma'), 3),
#  (('sempr', 'compro', 'site', 'lannist'), 3),
#  (('site', 'lannist', 'nunca', 'problema'), 3),
#  (('boa', 'tard', 'não', 'recebi'), 3),
#  (('não', 'recomendo', 'poi', 'não'), 3),
#  (('comprei', '3', 'unidad', 'produto'), 3),
#  (('3', 'unidad', 'produto', 'vieram'), 3),
#  (('unidad', 'produto', 'vieram', '2'), 3),
#  (('produto', 'vieram', '2', 'unidad'), 3),
#  (('vieram', '2', 'unidad', 'não'), 3),
#  (('2', 'unidad', 'não', 'correspond'), 3),
#  (('unidad', 'não', 'correspond', 'comprei'), 3),
#  (('não', 'correspond', 'comprei', 'devido'), 3),
#  (('correspond', 'comprei', 'devido', 'opinião'), 3),
#  (('comprei', 'devido', 'opinião', 'negativa'), 3),
#  (('devido', 'opinião', 'negativa', 'relação'), 3),
#  (('opinião', 'negativa', 'relação', 'vendedor'), 3),
#  (('negativa', 'relação', 'vendedor', 'poi'), 3),
#  (('relação', 'vendedor', 'poi', 'não'), 3),
#  (('vendedor', 'poi', 'não', 'não'), 3),
#  (('poi', 'não', 'não', 'cumpriu'), 3),
#  (('não', 'não', 'cumpriu', 'prometido'), 3),
#  (('mê', 'não', 'recebi', 'produto'), 3),
#  (('momento', 'não', 'obtiv', 'retorno'), 3),
#  (('produto', 'veio', 'errado', 'ainda'), 3),
#  (('veio', 'errado', 'ainda', 'não'), 3),
#  (('ainda', 'não', 'recebi', 'nenhum'), 3),
#  (('não', 'recebi', 'nenhum', 'contato'), 3),
#  (('produto', 'veio', 'errado', 'comprei'), 3),
#  (('não', 'consigo', 'rastrear', 'produto'), 3),
#  (('comprei', 'produto', 'mandaram', 'outro'), 3),
#  (('produto', 'mandaram', 'outro', 'produto'), 3),
#  (('gostaria', 'saber', 'motivo', 'não'), 3),
#  (('não', 'recebi', 'produto', 'tento'), 3),
#  (('recebi', 'produto', 'comprei', 'comprei'), 3),
#  (('produto', 'não', 'consigo', 'entrar'), 3),
#  (('não', 'posso', 'avaliar', 'produto'), 3),
#  (('paguei', 'produto', 'não', 'entregu'), 3),
#  (('pedido', 'não', 'entregu', 'prazo'), 3),
#  (('prazo', 'máximo', 'entrega', 'dia'), 3),
#  (('pedido', 'entregu', 'porém', 'não'), 3),
#  (('hoje', 'produto', 'não', 'entregu'), 3),
#  (('momento', 'produto', 'não', 'entregu'), 3),
#  (('produto', 'não', 'entregu', 'sendo'), 3),
#  (('não', 'entregu', 'sendo', 'prazo'), 3),
#  (('2018', 'ainda', 'não', 'recebi'), 3),
#  (('bom', 'dia', 'recebi', 'produto'), 3),
#  (('momento', 'não', 'nenhum', 'retorno'), 3),
#  (('mail', 'perguntando', 'recebi', 'produto'), 3),
#  (('não', 'posso', 'avaliar', 'ainda'), 3),
#  (('2', 'recebi', 'apena', '1'), 3),
#  (('recebi', 'apena', '1', 'nota'), 3),
#  (('não', 'recebi', 'nota', 'fiscal'), 3),
#  (('produto', 'entregu', 'não', 'comprado'), 3),
#  (('não', 'recebi', 'nenhum', 'posicionamento'), 3),
#  (('problema', 'entrega', 'não', 'recebi'), 3),
#  (('recebi', 'produto', 'porém', 'não'), 3),
#  (('não', 'recebi', 'outro', 'produto'), 3),
#  (('produto', 'nota', 'fiscal', 'veio'), 3),
#  (('nota', 'fiscal', 'veio', 'valor'), 3),
#  (('entrega', 'produto', 'diferent', 'solicitado'), 3),
#  (('produto', 'diferent', 'solicitado', 'aguardo'), 3),
#  (('diferent', 'solicitado', 'aguardo', 'orientação'), 3),
#  (('porém', 'não', 'recebi', 'produto'), 3),
#  (('consta', 'site', 'produto', 'entregu'), 3),
#  (('2', 'produto', 'recebi', 'apena'), 3),
#  (('comprei', 'doi', 'cartucho', 'tinta'), 3),
#  (('recebi', 'produto', 'ainda', 'prazo'), 3),
#  (('veio', 'defeito', 'não', 'funciona'), 3),
#  (('comprei', 'doi', 'iten', 'entregu'), 3),
#  (('comprei', '3', 'luminária', 'recebi'), 3),
#  (('não', 'recebi', 'produto', 'rastreamento'), 3),
#  (('boa', 'noit', 'produto', 'não'), 3),
#  (('produto', 'chegou', 'prazo', 'porem'), 3),
#  (('porqu', 'ainda', 'não', 'recebi'), 3),
#  (('dia', '20', '12', 'não'), 3),
#  (('objeto', 'ainda', 'não', 'chegou'), 3),
#  (('comprei', '2', 'unidad', 'recebi'), 3),
#  (('fiz', 'reclamação', 'site', 'agora'), 3),
#  (('agora', 'não', 'recebi', 'resposta'), 3),
#  (('nao', 'recebi', 'produto', 'ja'), 3),
#  (('produto', 'consta', 'entregu', 'correio'), 3),
#  (('produto', 'chegou', 'ant', 'data'), 3),
#  (('gostaria', 'saber', 'porqu', 'não'), 3),
#  (('ainda', 'não', 'recebi', 'nenhuma'), 3),
#  (('1', 'mê', 'ainda', 'não'), 3),
#  (('não', 'consigo', 'rastrear', 'outro'), 3),
#  (('recebi', 'produto', 'não', 'posso'), 3),
#  (('recebi', 'produto', 'errado', 'pedi'), 3),
#  (('recebi', 'produto', 'não', 'nenhum'), 3),
#  (('produto', 'não', 'entregu', 'conform'), 3),
#  (('vendedor', 'entrou', 'contato', 'comigo'), 3),
#  (('produto', 'não', 'entregu', 'poi'), 3),
#  (('agora', 'não', 'obtiv', 'nenhuma'), 3),
#  (('nota', 'fiscal', 'veio', 'constando'), 3),
#  (('não', 'entregu', 'present', 'momento'), 3),
#  (('agora', 'ainda', 'não', 'recebi'), 3),
#  (('dia', '19', '02', 'hoje'), 3),
#  (('não', 'entregu', 'conform', 'prazo'), 3),
#  (('venderam', 'produto', 'não', 'estoqu'), 3),
#  (('produto', 'não', 'estoqu', 'não'), 3),
#  (('data', 'produto', 'não', 'entregu'), 3),
#  (('não', 'recebi', 'produto', 'aguardo'), 3),
#  (('produto', 'não', 'tão', 'bom'), 3),
#  (('não', 'consigo', 'falar', 'loja'), 3),
#  (('não', 'recebi', 'produto', 'casa'), 3),
#  (('não', 'chegou', 'data', 'prevista'), 3),
#  (('não', 'recebi', 'não', 'nenhuma'), 3),
#  (('produto', 'não', 'chegou', 'data'), 3),
#  (('comprei', '3', 'luminaria', 'recebi'), 3),
#  (('dia', '26', '03', 'hoje'), 3),
#  (('chegou', 'ant', 'prazo', 'materi'), 3),
#  (('produto', 'não', 'nada', 'ver'), 3),
#  (('produto', 'q', 'recebi', 'não'), 3),
#  (('hoje', 'nao', 'recebi', 'produto'), 3),
#  (('luminária', 'recebi', 'apena', '1'), 3),
#  (('não', 'recomendo', 'loja', 'pra'), 3),
#  (('recomendo', 'loja', 'pra', 'ninguém'), 3),
#  (('passou', 'prazo', 'ainda', 'não'), 3),
#  (('pedi', '2', 'unidad', 'recebi'), 3),
#  (('não', 'chegou', 'não', 'consigo'), 3),
#  (('sempr', 'comprei', 'baratheon', 'nunca'), 3),
#  (('hoje', 'ainda', 'não', 'recebi'), 3),
#  (('poi', 'ainda', 'nao', 'recebi'), 3),
#  (('consta', 'entregu', 'não', 'recebi'), 3),
#  (('recebi', 'outro', 'produto', 'não'), 3),
#  (('produto', 'empresa', 'não', 'entrou'), 3),
#  (('produto', 'veio', 'quebrado', 'quero'), 3),
#  (('não', 'chegou', 'prazo', 'entrega'), 3),
#  (('ate', 'agora', 'não', 'chegou'), 3),
#  (('ja', 'paguei', 'primeira', 'parcela'), 3),
#  (('dentro', 'prazo', 'porem', 'nao'), 3),
#  (('produto', 'veio', 'embalado', 'apena'), 3),
#  (('veio', 'embalado', 'apena', 'frágil'), 3),
#  (('embalado', 'apena', 'frágil', 'envelop'), 3),
#  (('apena', 'frágil', 'envelop', 'ocasion'), 3),
#  (('frágil', 'envelop', 'ocasion', 'fato'), 3),
#  (('envelop', 'ocasion', 'fato', 'caixa'), 3),
#  (('ocasion', 'fato', 'caixa', 'cartucho'), 3),
#  (('fato', 'caixa', 'cartucho', 'ficar'), 3),
#  (('caixa', 'cartucho', 'ficar', 'totalment'), 3),
#  (('não', 'posso', 'opinar', 'sobr'), 3),
#  (('nota', 'fiscal', 'constam', 'dua'), 3),
#  (('produto', 'mê', 'não', 'recebi'), 3),
#  (('momento', 'não', 'recebi', 'compra'), 3),
#  (('paguei', 'frete', 'pra', 'receb'), 3),
#  (('pedido', 'veio', 'faltando', '1'), 3),
#  (('fiz', 'compra', 'doi', 'produto'), 3),
#  (('ainda', 'não', 'usei', 'produto'), 3),
#  (('não', 'posso', 'opinar', 'poi'), 3),
#  (('retirar', 'produto', 'agência', 'correio'), 3),
#  (('boa', 'tard', 'recebi', 'apena'), 3),
#  (('quero', 'devolv', 'produto', 'não'), 3),
#  (('entrega', 'não', 'recomendo', 'loja'), 3),
#  (('entrega', 'dia', '26', '03'), 3),
#  (('tentei', 'entrar', 'contato', 'lannist'), 3),
#  (('produto', 'agora', 'não', 'entregu'), 3),
#  (('comprei', 'dua', 'cortina', 'porém'), 3),
#  (('dua', 'unidad', 'produto', 'apena'), 3),
#  (('sendo', 'nota', 'fiscal', 'constam'), 3),
#  (('dia', '05', '01', 'agora'), 3),
#  (('produto', 'boa', 'qualidad', 'porém'), 3),
#  (('quero', 'devolv', 'produto', 'porqu'), 3),
#  (('não', 'consegui', 'efetuar', 'troca'), 3),
#  (('sempr', 'compro', 'loja', 'lannist'), 3),
#  (('vez', 'não', 'recebi', 'produto'), 3),
#  (('recebi', 'apena', '1', 'item'), 3),
#  (('dei', '3', 'estrela', 'poi'), 3),
#  (('ainda', 'não', 'recebi', 'compra'), 3),
#  (('ainda', 'não', 'obtiv', 'retorno'), 3),
#  (('não', 'emitiu', 'nota', 'fiscal'), 3),
#  (('2018', 'não', 'recebi', 'produto'), 3),
#  (('não', 'recebi', 'produto', 'correio'), 3),
#  (('recebi', 'produto', 'hoje', 'não'), 3),
#  (('vez', 'ainda', 'não', 'recebi'), 3),
#  (('produto', 'ainda', 'não', 'recebi'), 3),
#  (('momento', 'nao', 'recebi', 'produto'), 3),
#  (('cor', 'preta', 'veio', 'cor'), 3),
#  (('não', 'consegui', 'entrar', 'contato'), 3),
#  (('recebi', 'produto', 'dinheiro', 'volta'), 3),
#  (('momento', 'não', 'recebi', 'nada'), 3),
#  (('não', 'chegou', 'entrei', 'contato'), 3),
#  (('produto', 'não', 'entregu', 'data'), 3),
#  (('prazo', 'entrega', 'não', 'cumprido'), 3),
#  (('não', 'recebi', 'produto', 'satisfação'), 3),
#  (('momento', 'não', 'recebi', 'pedido'), 3),
#  (('avaliar', 'porqu', 'não', 'recebi'), 3),
#  (('não', 'recebi', 'produto', 'atendimento'), 3),
#  (('comprei', 'dua', 'cortina', 'recebi'), 3),
#  (('dua', 'cortina', 'recebi', 'apena'), 3),
#  (('demora', 'entrega', 'ainda', 'não'), 3),
#  (('gostaria', 'saber', 'vão', 'entregar'), 3),
#  (('produto', 'veio', 'defeito', 'espero'), 3),
#  (('veio', 'defeito', 'espero', 'não'), 3),
#  (('defeito', 'espero', 'não', 'demor'), 3),
#  (('espero', 'não', 'demor', 'troca'), 3),
#  (('não', 'demor', 'troca', 'poi'), 3),
#  (('demor', 'troca', 'poi', 'comprada'), 3),
#  (('recebi', 'produto', 'ninguém', 'entrou'), 3),
#  (('produto', 'ninguém', 'entrou', 'contato'), 3),
#  (('não', 'recebi', 'produto', 'então'), 3),
#  (('quero', 'dinheiro', 'volta', 'produto'), 3),
#  (('entregu', 'prazo', 'porém', 'veio'), 3),
#  (('produto', 'não', 'funciona', 'não'), 3),
#  (('peço', 'produto', 'código', 'vem'), 3),
#  (('produto', 'código', 'vem', 'outro'), 3),
#  (('código', 'vem', 'outro', 'totalment'), 3),
#  (('entrega', 'dia', '04', '04'), 3),
#  (('não', 'recebi', 'gostaria', 'saber'), 3),
#  (('recebi', 'soment', '1', 'item'), 3),
#  (('entrega', 'dentro', 'prazo', 'porém'), 3),
#  (('não', 'entregu', 'entrei', 'contato'), 3),
#  (('recebi', 'produto', 'bem', 'ant'), 3),
#  (('recebi', 'produto', 'cor', 'errada'), 3),
#  (('produto', 'recebi', 'outro', 'totalment'), 3),
#  (('produto', 'veio', 'cor', 'errada'), 3),
#  (('entrega', 'ninguém', 'entrou', 'contato'), 3),
#  (('produto', 'previsão', 'entrega', 'dia'), 3),
#  (('nao', 'recebi', 'produto', 'recebi'), 3),
#  (('não', 'chegou', 'dentro', 'prazo'), 3),
#  (('compra', 'não', 'recebi', 'produto'), 3),
#  (('produto', 'agora', 'não', 'chegou'), 3),
#  (('sempr', 'compro', 'lannist', 'nunca'), 3),
#  (('passou', 'prazo', 'produto', 'não'), 3),
#  (('compra', 'produto', 'ainda', 'não'), 3),
#  (('prazo', 'entrega', 'agora', 'não'), 3),
#  (('dia', 'prazo', 'máximo', 'entrega'), 3),
#  (('não', 'entregu', 'quero', 'saber'), 3),
#  (('data', 'prevista', 'entrega', 'dia'), 3),
#  (('produto', 'nao', 'chegou', 'nao'), 3),
#  (('vou', 'querer', 'dinheiro', 'volta'), 3),
#  (('posso', 'avaliar', 'não', 'recebi'), 3),
#  (('bom', 'dia', 'recebi', 'pedido'), 3),
#  (('quero', 'devolv', 'produto', 'comprei'), 3),
#  (('devolv', 'produto', 'comprei', 'veio'), 3),
#  (('produto', 'comprei', 'veio', 'outro'), 3),
#  (('comprei', 'veio', 'outro', 'quero'), 3),
#  (('veio', 'outro', 'quero', 'dinheiro'), 3),
#  (('não', 'recebi', 'então', 'não'), 3),
#  (('não', 'sei', 'culpa', 'loja'), 3),
#  (('recebi', 'produto', 'porem', 'não'), 3),
#  (('ate', 'present', 'momento', 'nao'), 3),
#  (('produto', 'não', 'origin', 'qualidad'), 3),
#  (('entrega', 'ant', 'prazo', 'produto'), 3),
#  (('gostei', 'produto', 'chegou', 'ant'), 3),
#  (('produto', 'veio', 'mal', 'embalado'), 3),
#  (('produto', 'errado', 'nota', 'fiscal'), 3),
#  (('fiz', 'pedido', 'dua', 'unidad'), 3),
#  (('não', 'recebi', 'produto', 'sei'), 3),
#  (('comprei', '4', 'produto', 'recebi'), 3),
#  (('ninguém', 'entrou', 'contato', 'comigo'), 3),
#  (('nota', 'fiscal', 'consta', 'doi'), 3),
#  (('tentando', 'entrar', 'contato', 'loja'), 3),
#  (('esgot', 'ainda', 'não', 'recebi'), 2),
#  (('não', 'chegou', 'prazo', 'estipulado'), 2),
#  (('dua', 'unidad', 'recebi', 'agora'), 2),
#  (('recebi', 'produto', 'consta', 'sistema'), 2),
#  (('doi', 'produto', 'recebi', 'soment'), 2),
#  (('1', 'mê', 'apó', 'compra'), 2),
#  (('bem', 'rápido', 'porém', 'veio'), 2),
#  (('porém', 'veio', 'outro', 'produto'), 2),
#  (('veio', 'outro', 'produto', 'não'), 2),
#  (('2', 'frasco', '60', 'cápsula'), 2),
#  (('embalagem', 'deixou', 'desejar', 'pouco'), 2),
#  (('deixou', 'desejar', 'pouco', 'produto'), 2),
#  (('desejar', 'pouco', 'produto', 'não'), 2),
#  (('pouco', 'produto', 'não', 'danificado'), 2),
#  (('produto', 'não', 'danificado', 'caixa'), 2),
#  (('não', 'danificado', 'caixa', 'toda'), 2),
#  (('não', 'gostei', 'produto', 'materi'), 2),
#  (('veio', 'outro', 'mandei', 'msg'), 2),
#  (('porém', 'não', 'obtiv', 'resposta'), 2),
#  (('passou', 'data', 'prevista', 'entrega'), 2),
#  (('ainda', 'não', 'recebi', 'poi'), 2),
#  (('comprei', 'dua', 'mochila', 'recebi'), 2),
#  (('2', 'cartucho', 'entregaram', 'apena'), 2),
#  (('cartucho', 'entregaram', 'apena', '1'), 2),
#  (('agora', 'não', 'recebi', 'nada'), 2),
#  (('site', 'ainda', 'não', 'obtiv'), 2),
#  (('não', 'entregu', 'fiz', 'reclamação'), 2),
#  (('quero', 'cancelar', 'compra', 'poi'), 2),
#  (('compra', 'poi', 'paguei', 'frete'), 2),
#  (('poi', 'paguei', 'frete', 'não'), 2),
#  (('não', 'ninguém', 'casa', 'receb'), 2),
#  (('película', 'menor', 'tela', 'celular'), 2),
#  (('não', 'consegui', 'usar', 'produto'), 2),
#  (('15', 'dia', 'ainda', 'não'), 2),
#  (('unidad', 'recebi', 'apena', 'unidad'), 2),
#  (('comprei', '2', 'unidad', 'produto'), 2),
#  (('03', '2018', 'agora', 'não'), 2),
#  (('película', 'vidro', 'veio', 'defeito'), 2),
#  (('veio', 'capa', 'comprei', '3'), 2),
#  (('capa', 'comprei', '3', 'aí'), 2),
#  (('comprei', '3', 'aí', 'paguei'), 2),
#  (('3', 'aí', 'paguei', '100'), 2),
#  (('aí', 'paguei', '100', 'reai'), 2),
#  (('ainda', 'não', 'recebi', 'capa'), 2),
#  (('não', 'recebi', 'capa', 'sofá'), 2),
#  (('consigo', 'contato', 'lannist', 'telefon'), 2),
#  (('entrega', 'tentei', 'entrar', 'contato'), 2),
#  (('produto', 'momento', 'não', 'recebi'), 2),
#  (('boa', 'tard', 'produto', 'veio'), 2),
#  (('tempo', 'compro', 'loja', 'lannist'), 2),
#  (('nota', 'fiscal', '2', 'unidad'), 2),
#  (('comprei', 'capa', 'cor', 'preta'), 2),
#  (('recebi', 'produto', 'data', 'prevista'), 2),
#  (('doi', 'dia', 'apó', 'prazo'), 2),
#  (('compra', 'nada', 'produto', 'chegar'), 2),
#  (('ainda', 'não', 'recebi', 'encomenda'), 2),
#  (('produto', 'não', 'entregu', 'casa'), 2),
#  (('casa', 'q', 'ir', 'buscar'), 2),
#  (('q', 'ir', 'buscar', 'agência'), 2),
#  (('frete', 'ainda', 'assim', 'não'), 2),
#  (('produto', 'defeito', 'não', 'consigo'), 2),
#  (('produto', 'bom', 'entrega', 'rapida'), 2),
#  (('bom', 'entrega', 'rapida', 'frete'), 2),
#  (('chegou', 'ant', 'data', 'marcada'), 2),
#  (('chegou', 'apena', 'outro', 'não'), 2),
#  (('comprei', '6', 'cartucho', 'recebi'), 2),
#  (('não', 'veio', 'produto', 'correto'), 2),
#  (('80', 'algodão', '20', 'poliést'), 2),
#  (('não', 'chegou', 'produto', 'comprei'), 2),
#  (('pra', 'chegar', 'dia', '05'), 2),
#  (('não', 'entregaram', 'prazo', 'tá'), 2),
#  (('entregaram', 'prazo', 'tá', '30'), 2),
#  (('prazo', 'tá', '30', 'dia'), 2),
#  (('tá', '30', 'dia', 'mísera'), 2),
#  (('30', 'dia', 'mísera', 'tesoura'), 2),
#  (('dia', 'mísera', 'tesoura', 'comprar'), 2),
#  (('mísera', 'tesoura', 'comprar', 'aqui'), 2),
#  (('tesoura', 'comprar', 'aqui', 'pq'), 2),
#  (('comprar', 'aqui', 'pq', 'empresa'), 2),
#  (('aqui', 'pq', 'empresa', 'não'), 2),
#  (('pq', 'empresa', 'não', 'comprometeu'), 2),
#  (('empresa', 'não', 'comprometeu', 'manda'), 2),
#  (('não', 'comprometeu', 'manda', 'email'), 2),
#  (('comprometeu', 'manda', 'email', 'pra'), 2),
#  (('ainda', 'não', 'chegou', 'todo'), 2),
#  (('produto', 'não', 'entregu', 'porém'), 2),
#  (('nota', 'fiscal', 'emitida', 'dia'), 2),
#  (('dua', 'unidad', 'produto', 'veio'), 2),
#  (('produto', 'não', 'chegou', 'hoje'), 2),
#  (('20', 'dia', 'ainda', 'não'), 2),
#  (('agora', 'não', 'recebi', 'quero'), 2),
#  (('kit', 'tesoura', 'fio', 'navalha'), 2),
#  (('não', 'veio', 'acompanhado', 'nota'), 2),
#  (('quas', 'mê', 'fiz', 'pedido'), 2),
#  (('mê', 'fiz', 'pedido', 'produto'), 2),
#  (('fiz', 'pedido', 'produto', 'ainda'), 2),
#  (('pedido', 'produto', 'ainda', 'não'), 2),
#  (('quas', 'não', 'dá', 'pra'), 2),
#  (('não', 'dá', 'pra', 'ver'), 2),
#  (('não', 'recebi', 'ninguém', 'ligou'), 2),
#  (('dest', 'pedido', 'ainda', 'não'), 2),
#  (('boa', 'tard', 'comprei', 'produto'), 2),
#  (('além', 'disso', 'produto', 'não'), 2),
#  (('poi', 'pedido', 'veio', 'errado'), 2),
#  (('pedido', 'veio', 'errado', 'aguardo'), 2),
#  (('2', '00', 'x', '2'), 2),
#  (('recebi', 'produto', 'não', 'obtiv'), 2),
#  (('produto', 'não', 'obtiv', 'nenhuma'), 2),
#  (('produto', 'veio', 'lacr', 'violado'), 2),
#  (('dua', 'cadeira', 'veio', 'soment'), 2),
#  (('anúncio', 'não', 'condiz', 'produto'), 2),
#  (('compro', 'site', 'lannist', 'nunca'), 2),
#  (('quero', 'saber', 'aconteceu', 'entrega'), 2),
#  (('cartucho', 'hp', '933xl', 'origin'), 2),
#  (('trê', 'produto', 'recebi', 'apena'), 2),
#  (('não', 'recebi', 'produto', 'resposta'), 2),
#  (('cancelamento', 'compra', 'site', 'não'), 2),
#  (('compra', 'site', 'não', 'permitiu'), 2),
#  (('produto', 'entrei', 'contato', 'loja'), 2),
#  (('data', 'limit', 'entrega', 'produto'), 2),
#  (('produto', 'entregu', 'faltando', 'item'), 2),
#  (('nota', 'fiscal', 'consta', 'dua'), 2),
#  (('não', 'recebi', 'pedido', 'prazo'), 2),
#  (('não', 'satisfeita', 'compra', 'poi'), 2),
#  (('produto', 'chegou', 'perfeito', 'estado'), 2),
#  (('prazo', 'não', 'consigo', 'falar'), 2),
#  (('não', 'gostei', 'produto', 'qualidad'), 2),
#  (('hoje', '17', '03', 'não'), 2),
#  (('não', 'obtiv', 'retorno', 'produto'), 2),
#  (('recebi', 'produto', 'veio', 'errado'), 2),
#  (('errado', 'ainda', 'não', 'recebi'), 2),
#  (('03', '2017', 'agora', 'não'), 2),
#  (('gostaria', 'saber', 'vão', 'fazer'), 2),
#  (('não', 'recebi', 'produto', 'hj'), 2),
#  (('produto', 'hj', 'não', 'recebi'), 2),
#  (('marca', 'entregu', '2', 'produto'), 2),
#  (('entregu', '2', 'produto', 'realidad'), 2),
#  (('2', 'produto', 'realidad', 'recebi'), 2),
#  (('produto', 'realidad', 'recebi', 'apena'), 2),
#  (('realidad', 'recebi', 'apena', '1'), 2),
#  (('recebi', 'apena', '1', 'falta'), 2),
#  (('apena', '1', 'falta', 'tapet'), 2),
#  (('tentando', 'entrar', 'contato', 'lannist'), 2),
#  (('produto', 'quero', 'dinheiro', 'volta'), 2),
#  (('favor', 'respond', 'tesoura', 'desfiar'), 2),
#  (('respond', 'tesoura', 'desfiar', 'veio'), 2),
#  (('tesoura', 'desfiar', 'veio', 'defeito'), 2),
#  (('desfiar', 'veio', 'defeito', 'preciso'), 2),
#  (('produto', 'comprado', 'não', 'entregu'), 2),
#  (('produto', 'não', 'chegou', 'passou'), 2),
#  (('agora', 'não', 'obtiv', 'resposta'), 2),
#  (('produto', 'não', 'entregu', 'residência'), 2),
#  (('entregu', 'sendo', 'não', 'recebi'), 2),
#  (('sendo', 'não', 'recebi', 'nada'), 2),
#  (('ainda', 'não', 'entregu', 'aguardo'), 2),
#  (('vou', 'mandar', 'produto', 'volta'), 2),
#  (('mandar', 'produto', 'volta', 'esperando'), 2),
#  (('produto', 'volta', 'esperando', 'andamento'), 2),
#  (('volta', 'esperando', 'andamento', 'solicitação'), 2),
#  (('esperando', 'andamento', 'solicitação', 'devolução'), 2),
#  (('andamento', 'solicitação', 'devolução', 'fiz'), 2),
#  (('tentando', 'entrar', 'contato', 'dia'), 2),
#  (('consigo', 'entrar', 'contato', 'loja'), 2),
#  (('nota', 'fiscal', '2', 'produto'), 2),
#  (('recebi', 'produto', 'enviei', 'vário'), 2),
#  (('produto', 'enviei', 'vário', 'mail'), 2),
#  (('posso', 'avaliar', 'produto', 'poi'), 2),
#  (('avaliar', 'produto', 'poi', 'ainda'), 2),
#  (('além', 'não', 'entregarem', 'não'), 2),
#  (('não', 'entregarem', 'não', 'avisada'), 2),
#  (('present', 'não', 'recebi', 'produto'), 2),
#  (('2017', 'momento', 'não', 'recebi'), 2),
#  (('hoje', 'produto', 'não', 'chegou'), 2),
#  (('recebi', 'mail', 'dizendo', 'produto'), 2),
#  (('produto', 'poi', 'não', 'veio'), 2),
#  (('produto', 'entregu', 'diferent', 'produto'), 2),
#  (('2017', 'hoje', 'não', 'recebi'), 2),
#  (('nota', 'fiscal', 'nome', 'outra'), 2),
#  (('fiscal', 'nome', 'outra', 'pessoa'), 2),
#  (('ant', 'nota', 'fiscal', 'emitida'), 2),
#  (('comprei', 'quas', '2', 'mese'), 2),
#  (('prazo', 'entrega', 'dia', '27'), 2),
#  (('entrega', 'dia', '27', '03'), 2),
#  (('dia', '27', '03', '2018'), 2),
#  (('03', '2018', 'hoje', 'dia'), 2),
#  (('03', '2018', 'ainda', 'não'), 2),
#  (('agora', 'produto', 'não', 'chegou'), 2),
#  (('01', '2018', 'hoje', '26'), 2),
#  (('2018', 'hoje', '26', '02'), 2),
#  (('hoje', '26', '02', '2018'), 2),
#  (('não', 'entregu', 'não', 'recebi'), 2),
#  (('comprei', 'tre', 'produto', 'so'), 2),
#  (('tre', 'produto', 'so', 'chegou'), 2),
#  (('produto', 'so', 'chegou', 'doi'), 2),
#  (('cinza', '3', '00x2', '80'), 2),
#  (('00x2', '80', 'forro', 'microfibra'), 2),
#  (('80', 'forro', 'microfibra', 'ilhó'), 2),
#  (('forro', 'microfibra', 'ilhó', 'cromado'), 2),
#  (('dia', 'comprei', '2', 'produto'), 2),
#  (('recebi', '1', 'agora', 'não'), 2),
#  (('película', 'vidro', 'veio', 'errada'), 2),
#  (('jogo', 'lençói', 'cetim', 'recebi'), 2),
#  (('produto', 'entregu', 'momento', 'não'), 2),
#  (('apesar', 'constar', 'nota', 'fiscal'), 2),
#  (('comprei', '2', 'unidad', 'chegou'), 2),
#  (('2', 'unidad', 'chegou', 'soment'), 2),
#  (('entrega', 'ocorreu', 'dentro', 'prazo'), 2),
#  (('paguei', 'frete', 'ir', 'correio'), 2),
#  (('recebi', 'mail', 'perguntando', 'recebi'), 2),
#  (('posso', 'avaliar', 'ainda', 'não'), 2),
#  (('avaliar', 'ainda', 'não', 'recebi'), 2),
#  (('paguei', 'produto', 'não', 'recebi'), 2),
#  (('loja', 'pensa', 'pegar', 'dinheiro'), 2),
#  (('pensa', 'pegar', 'dinheiro', 'client'), 2),
#  (('pegar', 'dinheiro', 'client', 'não'), 2),
#  (('dinheiro', 'client', 'não', 'entrega'), 2),
#  (('produto', 'totalment', 'diferent', 'foto'), 2),
#  (('péssima', 'qualidad', 'aguardando', 'contato'), 2),
#  (('16', 'dia', 'útei', 'entrega'), 2),
#  (('comprei', '2', 'recebi', 'apena'), 2),
#  (('1', 'nota', 'fiscal', 'consta'), 2),
#  (('nota', 'fiscal', 'consta', '2'), 2),
#  (('não', 'vou', 'trocar', 'não'), 2),
#  (('não', 'cancelei', 'nada', 'paguei'), 2),
#  (('produto', 'momento', 'não', 'retorno'), 2),
#  (('agora', 'não', 'recebi', 'nenhum'), 2),
#  (('prazo', 'entrega', 'longo', '20'), 2),
#  (('entrega', 'longo', '20', 'dia'), 2),
#  (('não', 'recebi', 'produto', 'esperando'), 2),
#  (('tard', 'recebi', 'produto', 'porém'), 2),
#  (('espero', 'obter', 'resposta', 'encomenda'), 2),
#  (('obter', 'resposta', 'encomenda', 'comprei'), 2),
#  (('resposta', 'encomenda', 'comprei', '3'), 2),
#  (('encomenda', 'comprei', '3', 'control'), 2),
#  (('comprei', '3', 'control', 'remoto'), 2),
#  (('3', 'control', 'remoto', 'ar'), 2),
#  (('remoto', 'ar', 'condicionado', 'apena'), 2),
#  (('ar', 'condicionado', 'apena', 'recebi'), 2),
#  (('condicionado', 'apena', 'recebi', '1'), 2),
#  (('apena', 'recebi', '1', 'control'), 2),
#  (('recebi', '1', 'control', 'komeco'), 2),
#  (('1', 'control', 'komeco', '2'), 2),
#  (('control', 'komeco', '2', 'control'), 2),
#  (('komeco', '2', 'control', 'elgin'), 2),
#  (('2', 'control', 'elgin', 'pedido'), 2),
#  (('control', 'elgin', 'pedido', 'pago'), 2),
#  (('elgin', 'pedido', 'pago', 'entregu'), 2),
#  (('pedido', 'pago', 'entregu', '1'), 2),
#  (('pago', 'entregu', '1', 'control'), 2),
#  (('produto', 'enviado', 'não', 'condiz'), 2),
#  (('comprei', 'produto', 'dia', '06'), 2),
#  (('nota', 'fiscal', 'todo', 'iten'), 2),
#  (('realizei', 'compra', '3', 'unidad'), 2),
#  (('statu', 'aguardando', 'nota', 'fiscal'), 2),
#  (('paguei', 'frete', 'porém', 'não'), 2),
#  (('site', 'produto', 'entregu', 'dia'), 2),
#  (('recebi', 'lent', 'contato', 'grau'), 2),
#  (('lent', 'contato', 'grau', 'errado'), 2),
#  (('compra', 'devido', 'prazo', 'entrega'), 2),
#  (('veio', 'faltando', 'item', 'kit'), 2),
#  (('recebi', 'produto', 'cheio', 'defeito'), 2),
#  (('produto', 'cheio', 'defeito', 'solicitei'), 2),
#  (('cheio', 'defeito', 'solicitei', 'devolução'), 2),
#  (('defeito', 'solicitei', 'devolução', 'dinheiro'), 2),
#  (('solicitei', 'devolução', 'dinheiro', 'aguardando'), 2),
#  (('ruim', 'qualidad', 'borda', 'desenho'), 2),
#  (('qualidad', 'borda', 'desenho', 'veio'), 2),
#  (('borda', 'desenho', 'veio', 'aspecto'), 2),
#  (('desenho', 'veio', 'aspecto', 'queimado'), 2),
#  (('veio', 'aspecto', 'queimado', 'não'), 2),
#  (('aspecto', 'queimado', 'não', 'consigo'), 2),
#  (('queimado', 'não', 'consigo', 'tirar'), 2),
#  (('não', 'consigo', 'tirar', 'pelicula'), 2),
#  (('consigo', 'tirar', 'pelicula', 'frent'), 2),
#  (('tirar', 'pelicula', 'frent', 'espelho'), 2),
#  (('pelicula', 'frent', 'espelho', 'pra'), 2),
#  (('frent', 'espelho', 'pra', 'ver'), 2),
#  (('espelho', 'pra', 'ver', 'afet'), 2),
#  (('pra', 'ver', 'afet', 'adesivo'), 2),
#  (('ver', 'afet', 'adesivo', 'pra'), 2),
#  (('loja', 'lannist', 'produto', 'chegou'), 2),
#  (('estado', 'dentro', 'prazo', 'estipulado'), 2),
#  (('produto', 'veio', 'errado', 'não'), 2),
#  (('qualidad', 'não', 'nada', 'ver'), 2),
#  (('não', 'nada', 'ver', 'descrição'), 2),
#  (('comprei', 'doi', 'fone', 'ouvido'), 2),
#  (('site', 'produto', 'entregu', 'não'), 2),
#  (('produto', 'entregu', 'não', 'chegou'), 2),
#  (('so', 'entregu', 'nota', 'fiscal'), 2),
#  (('produto', 'veio', 'correto', 'prazo'), 2),
#  (('produto', 'deixou', 'desejar', 'fraco'), 2),
#  (('comprei', 'mous', 'gamer', 'usb'), 2),
#  (('mous', 'gamer', 'usb', '3200'), 2),
#  (('gamer', 'usb', '3200', 'dpi'), 2),
#  (('usb', '3200', 'dpi', 'ótico'), 2),
#  (('3200', 'dpi', 'ótico', '7'), 2),
#  (('dpi', 'ótico', '7', 'botõ'), 2),
#  (('ótico', '7', 'botõ', 'x'), 2),
#  (('7', 'botõ', 'x', 'soldado'), 2),
#  (('botõ', 'x', 'soldado', 'gamer'), 2),
#  (('comprei', 'outra', 'veze', 'bem'), 2),
#  (('veio', 'defeito', 'não', 'liga'), 2),
#  (('defeito', 'não', 'liga', 'não'), 2),
#  (('não', 'liga', 'não', 'funciona'), 2),
#  (('liga', 'não', 'funciona', 'quero'), 2),
#  (('produto', 'ainda', 'não', 'chegaram'), 2),
#  (('23', '12', '2017', 'não'), 2),
#  (('valor', 'pago', 'cartão', 'crédito'), 2),
#  (('não', 'restou', 'outra', 'alternativa'), 2),
#  (('restou', 'outra', 'alternativa', 'não'), 2),
#  (('chegou', 'ant', 'prazo', 'recebi'), 2),
#  (('ant', 'prazo', 'recebi', 'produto'), 2),
#  (('prazo', 'recebi', 'produto', 'diferent'), 2),
#  (('recebi', 'produto', 'diferent', 'mostrado'), 2),
#  (('produto', 'diferent', 'mostrado', 'descrição'), 2),
#  (('diferent', 'mostrado', 'descrição', 'imagen'), 2),
#  (('mostrado', 'descrição', 'imagen', 'lampada'), 2),
#  (('descrição', 'imagen', 'lampada', 'problema'), 2),
#  (('imagen', 'lampada', 'problema', 'fizemo'), 2),
#  (('lampada', 'problema', 'fizemo', 'notificação'), 2),
#  (('problema', 'fizemo', 'notificação', 'aguardando'), 2),
#  (('pedido', 'chegou', 'incompleto', 'aguardando'), 2),
#  (('entregaram', 'apena', '1', 'unidad'), 2),
#  (('compra', 'efetuada', '28', '11'), 2),
#  (('nota', 'fiscal', 'ainda', 'não'), 2),
#  (('não', 'recebi', 'produto', 'falha'), 2),
#  (('faz', 'mê', 'comprei', 'produto'), 2),
#  (('mê', 'comprei', 'produto', 'não'), 2),
#  (('prazo', 'porém', 'produto', 'entregu'), 2),
#  (('porém', 'produto', 'entregu', 'não'), 2),
#  (('03', 'ainda', 'não', 'chegou'), 2),
#  (('não', 'chegou', 'enviei', 'mensagem'), 2),
#  (('recebi', 'produto', 'errado', 'solicito'), 2),
#  (('contato', 'stark', 'não', 'obtiv'), 2),
#  (('não', 'obtiv', 'sucesso', 'tentei'), 2),
#  (('obtiv', 'sucesso', 'tentei', 'entrar'), 2),
#  (('sucesso', 'tentei', 'entrar', 'contato'), 2),
#  (('tentei', 'entrar', 'contato', 'empresa'), 2),
#  (('primeira', 'tentativa', 'entrega', 'não'), 2),
#  (('tentativa', 'entrega', 'não', 'ninguém'), 2),
#  (('não', 'recomendo', 'poi', 'recebi'), 2),
#  (('achei', 'corda', 'pescoço', 'grossa'), 2),
#  (('corda', 'pescoço', 'grossa', 'imagen'), 2),
#  (('pescoço', 'grossa', 'imagen', 'bem'), 2),
#  (('grossa', 'imagen', 'bem', 'fina'), 2),
#  (('imagen', 'bem', 'fina', 'ponta'), 2),
#  (('bem', 'fina', 'ponta', 'flecha'), 2),
#  (('fina', 'ponta', 'flecha', 'formato'), 2),
#  (('ponta', 'flecha', 'formato', 'côncavo'), 2),
#  (('flecha', 'formato', 'côncavo', 'atrá'), 2),
#  (('formato', 'côncavo', 'atrá', 'tipo'), 2),
#  (('côncavo', 'atrá', 'tipo', 'buraco'), 2),
#  (('atrá', 'tipo', 'buraco', 'imagen'), 2),
#  (('tipo', 'buraco', 'imagen', 'não'), 2),
#  (('ainda', 'aguardando', 'entrega', 'produto'), 2),
#  (('tentando', 'trocar', 'produto', 'não'), 2),
#  (('primeira', 'vez', 'problema', 'lannist'), 2),
#  (('nota', 'fiscal', 'não', 'emitida'), 2),
#  (('faltando', 'receb', 'produto', 'pulseira'), 2),
#  (('receb', 'produto', 'pulseira', 'masculina'), 2),
#  (('produto', 'pulseira', 'masculina', 'couro'), 2),
#  (('pulseira', 'masculina', 'couro', 'caveira'), 2),
#  (('masculina', 'couro', 'caveira', 'couro'), 2),
#  (('couro', 'caveira', 'couro', 'legítimo'), 2),
#  (('caveira', 'couro', 'legítimo', 'pedra'), 2),
#  (('couro', 'legítimo', 'pedra', 'preto'), 2),
#  (('recomendo', 'porém', 'produto', 'veio'), 2),
#  (('passou', 'prazo', 'entrega', 'nada'), 2),
#  (('carrinho', 'bebê', 'conforto', 'base'), 2),
#  (('entregu', 'bebê', 'conforto', 'base'), 2),
#  (('não', 'gostei', 'porqu', 'produto'), 2),
#  (('mal', 'embalado', 'nenhuma', 'proteção'), 2),
#  (('compra', 'dia', '13', '02'), 2),
#  (('não', 'recomendo', 'ninguém', 'comprar'), 2),
#  (('produto', 'entrega02', 'comprado', 'nest'), 2),
#  (('entrega02', 'comprado', 'nest', 'pedido'), 2),
#  (('comprado', 'nest', 'pedido', 'nao'), 2),
#  (('nest', 'pedido', 'nao', 'recebi'), 2),
#  (('pedido', 'nao', 'recebi', 'ainda'), 2),
#  (('nao', 'recebi', 'ainda', 'outro'), 2),
#  (('recebi', 'ainda', 'outro', 'entrega01'), 2),
#  (('ainda', 'outro', 'entrega01', 'recebi'), 2),
#  (('outro', 'entrega01', 'recebi', 'email'), 2),
#  (('entrega01', 'recebi', 'email', 'dificuldad'), 2),
#  (('recebi', 'email', 'dificuldad', 'entrega'), 2),
#  (('email', 'dificuldad', 'entrega', 'não'), 2),
#  (('não', 'funciona', 'não', 'carrega'), 2),
#  (('atraso', 'entrega', 'recebi', 'apena'), 2),
#  (('fiz', 'compra', '2', 'conjunto'), 2),
#  (('nota', 'fiscal', 'veio', 'nome'), 2),
#  (('nome', 'outra', 'pessoa', 'não'), 2),
#  (('não', 'enviaram', 'nota', 'fiscal'), 2),
#  (('não', 'chegou', 'preciso', 'saber'), 2),
#  (('preciso', 'saber', 'vai', 'chegar'), 2),
#  (('dia', '07', '03', '2018'), 2),
#  (('ainda', 'não', 'recebi', 'comprei'), 2),
#  (('não', 'recebi', 'comprei', 'dar'), 2),
#  (('recebi', 'comprei', 'dar', 'present'), 2),
#  (('não', 'recebi', 'produto', 'peço'), 2),
#  (('comprei', 'doi', 'produto', 'dia'), 2),
#  (('2', 'produto', 'não', 'recebi'), 2),
#  (('entregu', 'dia', '20', '12'), 2),
#  (('boa', 'noit', 'produto', 'veio'), 2),
#  (('produto', 'cancelado', 'nenhuma', 'explicação'), 2),
#  (('pedi', 'colcha', '100', 'algodão'), 2),
#  (('colcha', '100', 'algodão', 'veio'), 2),
#  (('100', 'algodão', 'veio', '100'), 2),
#  (('unidad', 'recebi', 'apena', '1'), 2),
#  (('produto', 'não', 'entregu', 'quer'), 2),
#  (('fevereiro', 'ainda', 'não', 'recebi'), 2),
#  (('recebi', 'produto', 'enviei', 'mail'), 2),
#  (('porém', 'nota', 'fiscal', 'veio'), 2),
#  (('ja', 'tentei', 'entrar', 'contato'), 2),
#  (('apesar', 'estar', 'prazo', 'entrega'), 2),
#  (('entrega', 'consta', 'produto', 'entregu'), 2),
#  (('não', 'posso', 'recomendar', 'poi'), 2),
#  (('posso', 'recomendar', 'poi', 'não'), 2),
#  (('recomendar', 'poi', 'não', 'recebi'), 2),
#  (('chegou', 'ant', 'prazo', 'não'), 2),
#  (('entrou', 'contato', 'comigo', 'apó'), 2),
#  (('comprei', '2', 'iten', 'recebi'), 2),
#  (('paguei', '2', 'unidad', 'produto'), 2),
#  (('veio', 'cor', 'errada', 'comprei'), 2),
#  (('consta', 'entregu', 'correio', 'rj'), 2),
#  (('entregu', 'correio', 'rj', 'desd'), 2),
#  (('correio', 'rj', 'desd', 'dia'), 2),
#  (('rj', 'desd', 'dia', '20'), 2),
#  (('desd', 'dia', '20', '03'), 2),
#  (('dia', '20', '03', 'ainda'), 2),
#  (('20', '03', 'ainda', 'não'), 2),
#  (('03', 'ainda', 'não', 'saiu'), 2),
#  (('produto', 'chegou', 'divergindo', 'relação'), 2),
#  (('chegou', 'divergindo', 'relação', 'informado'), 2),
#  (('divergindo', 'relação', 'informado', 'site'), 2),
#  (('relação', 'informado', 'site', 'sobr'), 2),
#  (('informado', 'site', 'sobr', 'funcionamento'), 2),
#  (('site', 'sobr', 'funcionamento', 'falta'), 2),
#  (('sobr', 'funcionamento', 'falta', 'botão'), 2),
#  (('funcionamento', 'falta', 'botão', 'redutor'), 2),
#  (('não', 'posso', 'comentar', 'poi'), 2),
#  (('posso', 'comentar', 'poi', 'ainda'), 2),
#  (('comentar', 'poi', 'ainda', 'não'), 2),
#  (('prazo', 'entrega', 'não', 'recebi'), 2),
#  (('encomenda', 'ainda', 'não', 'chegou'), 2),
#  (('tentando', 'devolv', 'produto', 'não'), 2),
#  (('produto', 'não', 'entregu', 'corretament'), 2),
#  (('fiz', 'compra', '2', 'toner'), 2),
#  (('2', 'produto', 'fiz', 'reclamação'), 2),
#  (('não', 'recebi', 'nenhuma', 'explicação'), 2),
#  (('produto', 'nao', 'entraram', 'contato'), 2),
#  (('entrar', 'contato', 'loja', 'não'), 2),
#  (('momento', 'não', 'entregu', 'quas'), 2),
#  (('não', 'entregu', 'quas', '1'), 2),
#  (('entregu', 'quas', '1', 'mê'), 2),
#  (('quas', '1', 'mê', 'ainda'), 2),
#  (('não', 'chegou', 'ainda', 'passou'), 2),
#  (('chegou', 'ainda', 'passou', 'prazo'), 2),
#  (('quero', 'devolução', 'valor', 'pago'), 2),
#  (('produto', 'veio', 'caixa', 'origin'), 2),
#  (('então', 'gostei', 'veio', 'diferent'), 2),
#  (('gostei', 'veio', 'diferent', 'pedi'), 2),
#  (('veio', 'diferent', 'pedi', 'gostei'), 2),
#  (('diferent', 'pedi', 'gostei', 'entrega'), 2),
#  (('pedi', 'gostei', 'entrega', 'bem'), 2),
#  (('entrega', 'prazo', 'produto', 'correto'), 2),
#  (('produto', 'previsto', 'chegar', 'dia'), 2),
#  (('produto', 'não', 'entregu', 'ate'), 2),
#  (('estorno', 'valor', 'devolução', 'produto'), 2),
#  (('recebi', 'mail', 'lannist', 'perguntando'), 2),
#  (('não', 'recebi', 'mercadoria', 'não'), 2),
#  (('quas', 'doi', 'mese', 'ainda'), 2),
#  (('doi', 'mese', 'ainda', 'não'), 2),
#  (('não', 'recebi', 'produto', 'dentro'), 2),
#  (('recebi', 'produto', 'tento', 'entrar'), 2),
#  (('produto', 'tento', 'entrar', 'contato'), 2),
#  (('entregu', 'dentro', 'prazo', 'produto'), 2),
#  (('parec', 'plástico', 'encapar', 'caderno'), 2),
#  (('plástico', 'encapar', 'caderno', 'fino'), 2),
#  (('encapar', 'caderno', 'fino', 'não'), 2),
#  (('caderno', 'fino', 'não', 'parec'), 2),
#  (('fino', 'não', 'parec', 'nada'), 2),
#  (('não', 'parec', 'nada', 'descrito'), 2),
#  (('parec', 'nada', 'descrito', 'não'), 2),
#  (('nada', 'descrito', 'não', 'blackout'), 2),
#  (('descrito', 'não', 'blackout', 'desenho'), 2),
#  ...]
